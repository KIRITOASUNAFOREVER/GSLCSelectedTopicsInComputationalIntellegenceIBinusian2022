# %%
#------------------------------------------------------------------------------+
#   Selected Topics in Computational Intelligence I (COMP8038041)              #
#   Artificial Bee Colony (ABC) Algorithm with Python                          #
#   Kelas : LTY1                                                               #
#   Dosen : Amalia Zahra, S.Kom.,Ph.D.                                         #
#------------------------------------------------------------------------------+

# %%
import numpy as np
import random as rand
import time

# %%
class ArtificialBeeColony:

    def __init__(self, D, Lb, Ub, n, generation, ans, func):
        self.D = D
        self.Lb = Lb
        self.Ub = Ub
        self.n = n
        self.generation = generation
        self.ans = ans
        self.func = func
        self.bestFunc = 0
        self.bestFoodSourceArray = np.zeros(D)
        self.foodSourceArray = np.ones((n,D))
        self.tmpFoodSourceArray = np.ones(D)
        self.funcArray = np.ones(n)
        self.fitnessArray = np.ones(n)
        self.trialArray = np.zeros(n)
        self.pArray = np.zeros(n)
        
    def fitness(self,X):
        if(X >= 0):
            return 1/(1 + X)
        else:
            return 1 + abs(X)

    def generateNew(self,X,Xp):
        Xnew = X + rand.uniform(-1,1)*(X - Xp)
        if(Xnew < self.Lb): return self.Lb
        elif(Xnew > self.Ub): return self.Ub
        else: return Xnew

    def updateSolution(self,index):
        randVariableToChange = rand.randint(0,self.D-1)
        randPartner = index
        while(randPartner == index):
            randPartner = rand.randint(0,self.n-1)

        for j in range(self.D):
            self.tmpFoodSourceArray[j] = self.foodSourceArray[index][j]
        self.tmpFoodSourceArray[randVariableToChange] = self.generateNew(self.foodSourceArray[index][randVariableToChange], self.foodSourceArray[randPartner][randVariableToChange])
        
        if(self.ans == 0): 
            oriVal = self.funcArray[index]
            newVal = self.func(self.tmpFoodSourceArray,self.D)
        elif(self.ans == 1):
            oriVal = self.fitnessArray[index]
            newVal = self.fitness(self.func(self.tmpFoodSourceArray,self.D))

        if(newVal < oriVal):
            self.foodSourceArray[index][randVariableToChange] = self.tmpFoodSourceArray[randVariableToChange]
            self.funcArray[index] = self.func(self.tmpFoodSourceArray,self.D)
            self.fitnessArray[index] = self.fitness(self.func(self.tmpFoodSourceArray,self.D))
            self.trialArray[index] = 0
        else:
            self.trialArray[index] = self.trialArray[index] + 1
            
    def printLocalBestSolution_MAX(self):
        localBest = int(np.where(self.funcArray == self.funcArray.max())[0])
        print("Local Best Food Source:", self.foodSourceArray[localBest])
        print("local Best F(x) =",self.funcArray.max())
        if(self.funcArray.max() > self.bestFunc):
            for i in range(self.D):
                self.bestFoodSourceArray[i] = self.foodSourceArray[localBest][i]
            self.bestFunc = self.funcArray.max()
            
    def printLocalBestSolution_MIN(self):
        localBest = int(np.where(self.funcArray == self.funcArray.min())[0])
        print("Local Best Food Source:", self.foodSourceArray[localBest])
        print("local Best F(x) =",self.funcArray.min())
        if(self.funcArray.min() < self.bestFunc):
            for i in range(self.D):
                self.bestFoodSourceArray[i] = self.foodSourceArray[localBest][i]
            self.bestFunc = self.funcArray.min()
        
    def printCurrentSolution(self):
        print("==================================")
        print("foodSourceArray\n", self.foodSourceArray)
        print("funcArray\n", self.funcArray)
        print("fitnessArray\n", self.fitnessArray)
        print("trialArray\n", self.trialArray)
        print("==================================")
    
    def init(self):
        if(self.ans == 0): self.bestFunc = float("inf")
        elif(self.ans == 1): self.bestFunc = -float("inf")
            
        for i in range(self.n):
            for j in range(self.D):
                self.foodSourceArray[i][j] = rand.uniform(self.Lb, self.Ub)
            self.funcArray[i] = self.func(self.foodSourceArray[i,:],self.D)
            self.fitnessArray[i] = self.fitness(self.funcArray[i])
            
    def doRun(self):
        start = time.time()
        self.init()
            
        for gen in range(self.generation):
            print("Generation:", gen+1)

            #Employed Bee Phase
            for i in range(self.n):
                self.updateSolution(i)

            #Onlooker Bee Phase
            for i in range(self.n):
                self.pArray[i] = self.fitnessArray[i]/self.fitnessArray.sum()
            for i in range(self.n):
                if(rand.random() < self.pArray[i]):
                    self.updateSolution(i)
            
            if(self.ans == 0): self.printLocalBestSolution_MIN()
            elif(self.ans == 1): self.printLocalBestSolution_MAX()
            
            #Scout Bee Phase
            limit = 1
            for i in range(self.n):
                if(self.trialArray[i] > limit):
                    for j in range(self.D):
                        self.foodSourceArray[i][j] = rand.uniform(self.Lb, self.Ub)
                    self.funcArray[i] = self.func(self.foodSourceArray[i,:],self.D)
                    self.fitnessArray[i] = self.fitness(self.funcArray[i])
                    self.trialArray[i] = 0
        end = time.time()
        print("============================================")
        print("Time Consume：%f " % (end - start))
        print("Best Food Source:", self.bestFoodSourceArray)
        print("Best F(x) =", self.bestFunc)

# %%
def test(X,D):
    x1 = X[0]
    x2 = X[1]
    return x1**2 - x1*x2 + x2**2 + 2*x1 + 4*x2 + 3

# %%
# ArtificialBeeColony(D, Lb, Ub, n, generation, ans[min=0/max=1], func)
abc = ArtificialBeeColony(2, -5, 5, 10, 20, 1, test)
abc.doRun()
# Out:
# Generation: 1
# Local Best Food Source: [ 5.         -4.85659226]
# local Best F(x) = 66.4430806189561
# Generation: 2
# Local Best Food Source: [ 5. -5.]
# local Best F(x) = 68.0
# Generation: 3
# Local Best Food Source: [ 5. -5.]
# local Best F(x) = 68.0
# Generation: 4
# Local Best Food Source: [ 5. -5.]
# local Best F(x) = 68.0
# Generation: 5
# Local Best Food Source: [5.         4.11251444]
# local Best F(x) = 50.80026058720156
# Generation: 6
# Local Best Food Source: [5.         4.11251444]
# local Best F(x) = 50.80026058720156
# Generation: 7
# Local Best Food Source: [5.         4.33616899]
# local Best F(x) = 52.46619249111179
# Generation: 8
# Local Best Food Source: [-1.95462475  4.78716316]
# local Best F(x) = 54.3339997742307
# Generation: 9
# Local Best Food Source: [5.         4.79260514]
# local Best F(x) = 56.17645885743361
# Generation: 10
# Local Best Food Source: [ 5.         -4.71442303]
# local Best F(x) = 64.94020757486228
# Generation: 11
# Local Best Food Source: [-3.27952859  5.        ]
# local Best F(x) = 68.59389351947468
# Generation: 12
# Local Best Food Source: [-4.57416839  5.        ]
# local Best F(x) = 82.64552159101413
# Generation: 13
# Local Best Food Source: [-4.57416839  5.        ]
# local Best F(x) = 82.64552159101413
# Generation: 14
# Local Best Food Source: [-5.  5.]
# local Best F(x) = 88.0
# Generation: 15
# Local Best Food Source: [-5.  5.]
# local Best F(x) = 88.0
# Generation: 16
# Local Best Food Source: [-5.  5.]
# local Best F(x) = 88.0
# Generation: 17
# Local Best Food Source: [-4.78700091  4.77062302]
# local Best F(x) = 81.01968870476871
# Generation: 18
# Local Best Food Source: [-5.          4.77062302]
# local Best F(x) = 83.69445113092266
# Generation: 19
# Local Best Food Source: [-5.          4.98621042]
# local Best F(x) = 87.73818811756763
# Generation: 20
# Local Best Food Source: [-5.          4.98621042]
# local Best F(x) = 87.73818811756763
# ============================================
# Time Consume：0.017789
# Best Food Source: [-5.  5.]
# Best F(x) = 88.0

# %%
def RastriginFunc(X, D):
    funsum = 0
    for i in range(D):
        x = X[i]
        funsum += x**2-10*np.cos(2*np.pi*x)
    funsum += 10*D
    return funsum

# %%
# ArtificialBeeColony(D, Lb, Ub, n, generation, ans[min=0/max=1], func)
abcRast = ArtificialBeeColony(2, -5, 5, 5, 100, 1, RastriginFunc)
abcRast.doRun()
# Out:
# Generation: 1
# Local Best Food Source: [-4.55880806  3.35025935]
# local Best F(x) = 67.22307015964866
# Generation: 2
# Local Best Food Source: [-4.55880806  3.35025935]
# local Best F(x) = 67.22307015964866
# Generation: 3
# Local Best Food Source: [4.49544369 2.48301018]
# local Best F(x) = 66.31333205454764
# Generation: 4
# Local Best Food Source: [4.49544369 2.48301018]
# local Best F(x) = 66.31333205454764
# Generation: 5
# Local Best Food Source: [-4.7036526   4.70550052]
# local Best F(x) = 69.89688870592794
# Generation: 6
# Local Best Food Source: [-4.7036526   4.70550052]
# local Best F(x) = 69.89688870592794
# Generation: 7
# Local Best Food Source: [3.40856075 4.44811041]
# local Best F(x) = 69.27165940521637
# Generation: 8
# Local Best Food Source: [3.40856075 4.48625033]
# local Best F(x) = 70.1019135120761
# Generation: 9
# Local Best Food Source: [3.40856075 4.48625033]
# local Best F(x) = 70.1019135120761
# Generation: 10
# Local Best Food Source: [-2.40268194  4.6440662 ]
# local Best F(x) = 61.70362144793511
# Generation: 11
# Local Best Food Source: [ 2.63526685 -4.69334113]
# local Best F(x) = 59.057876174108664
# Generation: 12
# Local Best Food Source: [ 2.63526685 -4.69334113]
# local Best F(x) = 59.057876174108664
# Generation: 13
# Local Best Food Source: [ 2.63526685 -4.69334113]
# local Best F(x) = 59.057876174108664
# Generation: 14
# Local Best Food Source: [-5.         -2.48399229]
# local Best F(x) = 51.11967929211448
# Generation: 15
# Local Best Food Source: [-4.93876666  4.80645536]
# local Best F(x) = 54.75119704896974
# Generation: 16
# Local Best Food Source: [ 4.74077957 -2.35852139]
# local Best F(x) = 54.91900868792994
# Generation: 17
# Local Best Food Source: [ 4.74077957 -2.35852139]
# local Best F(x) = 54.91900868792994
# Generation: 18
# Local Best Food Source: [-4.78848106  4.60195167]
# local Best F(x) = 69.7306479224084
# Generation: 19
# Local Best Food Source: [-4.78848106  4.60195167]
# local Best F(x) = 69.7306479224084
# Generation: 20
# Local Best Food Source: [-4.78848106  4.60195167]
# local Best F(x) = 69.7306479224084
# Generation: 21
# Local Best Food Source: [ 3.32509385 -4.98832474]
# local Best F(x) = 50.511686141667745
# Generation: 22
# Local Best Food Source: [ 3.32509385 -4.98832474]
# local Best F(x) = 50.511686141667745
# Generation: 23
# Local Best Food Source: [-2.53718908 -5.        ]
# local Best F(x) = 51.165569564013396
# Generation: 24
# Local Best Food Source: [-2.53718908  4.48702078]
# local Best F(x) = 66.26569079853148
# Generation: 25
# Local Best Food Source: [-2.53718908  4.48702078]
# local Best F(x) = 66.26569079853148
# Generation: 26
# Local Best Food Source: [-2.53718908  4.48702078]
# local Best F(x) = 66.26569079853148
# Generation: 27
# Local Best Food Source: [4.54322085 1.61025534]
# local Best F(x) = 60.562197768086875
# Generation: 28
# Local Best Food Source: [-3.48990949  2.63315818]
# local Best F(x) = 55.79237930941957
# Generation: 29
# Local Best Food Source: [-5.         -4.31842107]
# local Best F(x) = 57.816580106155925
# Generation: 30
# Local Best Food Source: [-5.         -4.31842107]
# local Best F(x) = 57.816580106155925
# Generation: 31
# Local Best Food Source: [ 4.50805851 -4.97476377]
# local Best F(x) = 65.18349968803548
# Generation: 32
# Local Best Food Source: [ 4.50805851 -4.97476377]
# local Best F(x) = 65.18349968803548
# Generation: 33
# Local Best Food Source: [ 4.50805851 -4.58986866]
# local Best F(x) = 79.82436814035232
# Generation: 34
# Local Best Food Source: [ 4.50805851 -4.58986866]
# local Best F(x) = 79.82436814035232
# Generation: 35
# Local Best Food Source: [ 4.50805851 -4.58986866]
# local Best F(x) = 79.82436814035232
# Generation: 36
# Local Best Food Source: [ 4.54863564 -3.38161754]
# local Best F(x) = 69.02101063628996
# Generation: 37
# Local Best Food Source: [-4.57997799  3.65572682]
# local Best F(x) = 68.68727475577946
# Generation: 38
# Local Best Food Source: [-3.76094623  4.52618517]
# local Best F(x) = 63.808799362942
# Generation: 39
# Local Best Food Source: [-3.76094623  4.52618517]
# local Best F(x) = 63.808799362942
# Generation: 40
# Local Best Food Source: [-3.56998518  5.        ]
# local Best F(x) = 56.793461111173414
# Generation: 41
# Local Best Food Source: [-3.54363363 -2.49653226]
# local Best F(x) = 58.414173513761284
# Generation: 42
# Local Best Food Source: [-3.54363363 -2.49653226]
# local Best F(x) = 58.414173513761284
# Generation: 43
# Local Best Food Source: [ 3.31846627 -4.42076124]
# local Best F(x) = 63.511757897782154
# Generation: 44
# Local Best Food Source: [ 3.31846627 -4.42076124]
# local Best F(x) = 63.511757897782154
# Generation: 45
# Local Best Food Source: [ 3.31846627 -4.42076124]
# local Best F(x) = 63.511757897782154
# Generation: 46
# Local Best Food Source: [ 0.40568509 -4.40744207]
# local Best F(x) = 56.24112500125649
# Generation: 47
# Local Best Food Source: [ 2.3585076 -5.       ]
# local Best F(x) = 46.864267743874834
# Generation: 48
# Local Best Food Source: [ 0.4761618  -4.61925032]
# local Best F(x) = 58.77409335105028
# Generation: 49
# Local Best Food Source: [ 0.4761618  -4.61925032]
# local Best F(x) = 58.77409335105028
# Generation: 50
# Local Best Food Source: [ 4.21358451 -3.44975058]
# local Best F(x) = 56.8926434732376
# Generation: 51
# Local Best Food Source: [3.77056626 4.23815992]
# local Best F(x) = 50.147298281695484
# Generation: 52
# Local Best Food Source: [5.         4.23815992]
# local Best F(x) = 52.218751284233804
# Generation: 53
# Local Best Food Source: [5.         4.23815992]
# local Best F(x) = 52.218751284233804
# Generation: 54
# Local Best Food Source: [-1.69064296 -4.656563  ]
# local Best F(x) = 53.724846357403756
# Generation: 55
# Local Best Food Source: [-3.36076992 -4.656563  ]
# local Best F(x) = 64.92913228315382
# Generation: 56
# Local Best Food Source: [-3.36076992 -4.656563  ]
# local Best F(x) = 64.92913228315382
# Generation: 57
# Local Best Food Source: [-3.36076992 -4.656563  ]
# local Best F(x) = 64.92913228315382
# Generation: 58
# Local Best Food Source: [-1.33287733 -4.72259144]
# local Best F(x) = 50.768229437723896
# Generation: 59
# Local Best Food Source: [4.54554622 5.        ]
# local Best F(x) = 65.25529582189458
# Generation: 60
# Local Best Food Source: [4.54554622 5.        ]
# local Best F(x) = 65.25529582189458
# Generation: 61
# Local Best Food Source: [-5. -5.]
# local Best F(x) = 50.0
# Generation: 62
# Local Best Food Source: [-5.         -2.40493867]
# local Best F(x) = 49.052369292480904
# Generation: 63
# Local Best Food Source: [-4.50859343  0.69531561]
# local Best F(x) = 54.16501988301422
# Generation: 64
# Local Best Food Source: [-4.50859343  1.33111208]
# local Best F(x) = 56.963350527522344
# Generation: 65
# Local Best Food Source: [-4.50859343  1.33111208]
# local Best F(x) = 56.963350527522344
# Generation: 66
# Local Best Food Source: [-4.50859343  1.33111208]
# local Best F(x) = 56.963350527522344
# Generation: 67
# Local Best Food Source: [-4.46700577  1.73410386]
# local Best F(x) = 53.74426453164479
# Generation: 68
# Local Best Food Source: [-3.61660763 -2.34612053]
# local Best F(x) = 51.696986834370676
# Generation: 69
# Local Best Food Source: [-4.60385772 -3.6476099 ]
# local Best F(x) = 68.44457807972049
# Generation: 70
# Local Best Food Source: [-4.60385772 -3.6476099 ]
# local Best F(x) = 68.44457807972049
# Generation: 71
# Local Best Food Source: [-4.60385772 -3.6476099 ]
# local Best F(x) = 68.44457807972049
# Generation: 72
# Local Best Food Source: [ 5.         -4.46287382]
# local Best F(x) = 64.64639821813097
# Generation: 73
# Local Best Food Source: [ 4.5771714  -4.46287382]
# local Best F(x) = 79.44419478251498
# Generation: 74
# Local Best Food Source: [ 4.5771714  -4.46287382]
# local Best F(x) = 79.44419478251498
# Generation: 75
# Local Best Food Source: [ 4.5771714  -4.46287382]
# local Best F(x) = 79.44419478251498
# Generation: 76
# Local Best Food Source: [-5.         -3.47828154]
# local Best F(x) = 57.005478715457286
# Generation: 77
# Local Best Food Source: [-5.         -3.47828154]
# local Best F(x) = 57.005478715457286
# Generation: 78
# Local Best Food Source: [ 4.53460237 -2.30090728]
# local Best F(x) = 58.7657159369748
# Generation: 79
# Local Best Food Source: [4.53460237 1.4957515 ]
# local Best F(x) = 62.56091577196595
# Generation: 80
# Local Best Food Source: [4.53460237 1.4957515 ]
# local Best F(x) = 62.56091577196595
# Generation: 81
# Local Best Food Source: [4.53460237 1.4957515 ]
# local Best F(x) = 62.56091577196595
# Generation: 82
# Local Best Food Source: [ 4.65083763 -0.5968968 ]
# local Best F(x) = 56.0250005916328
# Generation: 83
# Local Best Food Source: [-3.53894641 -3.64280495]
# local Best F(x) = 61.733713293424636
# Generation: 84
# Local Best Food Source: [-3.51282793 -4.27110919]
# local Best F(x) = 61.87231369158781
# Generation: 85
# Local Best Food Source: [-3.51282793 -4.27110919]
# local Best F(x) = 61.87231369158781
# Generation: 86
# Local Best Food Source: [ 4.66368237 -1.48496468]
# local Best F(x) = 59.071962931621336
# Generation: 87
# Local Best Food Source: [-4.63486539  3.31898146]
# local Best F(x) = 63.31687551324635
# Generation: 88
# Local Best Food Source: [-4.63486539  3.31898146]
# local Best F(x) = 63.31687551324635
# Generation: 89
# Local Best Food Source: [-4.47776855  3.41862663]
# local Best F(x) = 70.36118896153732
# Generation: 90
# Local Best Food Source: [-4.49373667  3.41862663]
# local Best F(x) = 70.59410447222474
# Generation: 91
# Local Best Food Source: [-4.49373667  3.41862663]
# local Best F(x) = 70.59410447222474
# Generation: 92
# Local Best Food Source: [-4.49373667  3.41862663]
# local Best F(x) = 70.59410447222474
# Generation: 93
# Local Best Food Source: [-4.5005227  5.       ]
# local Best F(x) = 65.25465060573333
# Generation: 94
# Local Best Food Source: [-2.50233324  4.71137602]
# local Best F(x) = 60.8607263713875
# Generation: 95
# Local Best Food Source: [-2.50233324  4.71137602]
# local Best F(x) = 60.8607263713875
# Generation: 96
# Local Best Food Source: [-3.48404028  4.71137602]
# local Best F(x) = 66.68842985725448
# Generation: 97
# Local Best Food Source: [-3.48404028  4.71137602]
# local Best F(x) = 66.68842985725448
# Generation: 98
# Local Best Food Source: [-3.524217    3.55288652]
# local Best F(x) = 64.38052718422063
# Generation: 99
# Local Best Food Source: [-3.524217    3.55288652]
# local Best F(x) = 64.38052718422063
# Generation: 100
# Local Best Food Source: [5.         2.29534946]
# local Best F(x) = 43.07961905013279
# ============================================
# Time Consume：0.067888
# Best Food Source: [ 4.50805851 -4.58986866]
# Best F(x) = 79.82436814035232

# %%
def StyblinskiTangFunc(X, D):
    funsum = 0
    for i in range(D):
        x = X[i]
        funsum += (x**4) - 16*(x**2) + 5*x
    funsum *= 0.5
    return funsum

# %%
# ArtificialBeeColony(D, Lb, Ub, n, generation, ans[min=0/max=1], func)
abcTang = ArtificialBeeColony(2, -5, 5, 5, 100, 0, StyblinskiTangFunc)
abcTang.doRun()
# Out:
# Generation: 1
# Local Best Food Source: [ 2.80377389 -3.42963676]
# local Best F(x) = -58.477159125338275
# Generation: 2
# Local Best Food Source: [ 2.80377389 -3.42963676]
# local Best F(x) = -58.477159125338275
# Generation: 3
# Local Best Food Source: [-2.7318183   1.58661003]
# local Best F(x) = -51.688918014709486
# Generation: 4
# Local Best Food Source: [-2.18468077 -2.10786447]
# local Best F(x) = -63.1982551267855
# Generation: 5
# Local Best Food Source: [-2.73233368 -2.10786447]
# local Best F(x) = -69.63193387446182
# Generation: 6
# Local Best Food Source: [-2.73233368 -2.10786447]
# local Best F(x) = -69.63193387446182
# Generation: 7
# Local Best Food Source: [-2.76341665 -2.10786447]
# local Best F(x) = -69.7863312287806
# Generation: 8
# Local Best Food Source: [-2.76341665 -2.10786447]
# local Best F(x) = -69.7863312287806
# Generation: 9
# Local Best Food Source: [-2.76341665 -2.51615076]
# local Best F(x) = -75.7400860291389
# Generation: 10
# Local Best Food Source: [-2.76341665 -2.51615076]
# local Best F(x) = -75.7400860291389
# Generation: 11
# Local Best Food Source: [-1.77865925  2.45519435]
# local Best F(x) = -48.668985880823584
# Generation: 12
# Local Best Food Source: [2.05125569 2.03426211]
# local Best F(x) = -39.13858238792287
# Generation: 13
# Local Best Food Source: [ 2.57002181 -1.4346062 ]
# local Best F(x) = -42.53534755142962
# Generation: 14
# Local Best Food Source: [2.60906115 2.03426211]
# local Best F(x) = -44.223642588137864
# Generation: 15
# Local Best Food Source: [2.60906115 2.03426211]
# local Best F(x) = -44.223642588137864
# Generation: 16
# Local Best Food Source: [ 2.57002181 -1.72645552]
# local Best F(x) = -48.32114470849753
# Generation: 17
# Local Best Food Source: [ 2.57002181 -1.72645552]
# local Best F(x) = -48.32114470849753
# Generation: 18
# Local Best Food Source: [ 2.57002181 -1.72645552]
# local Best F(x) = -48.32114470849753
# Generation: 19
# Local Best Food Source: [-0.09648438 -2.88449947]
# local Best F(x) = -39.47558223513366
# Generation: 20
# Local Best Food Source: [-0.09648438 -2.88449947]
# local Best F(x) = -39.47558223513366
# Generation: 21
# Local Best Food Source: [ 1.26504348 -2.16866866]
# local Best F(x) = -40.34651033057709
# Generation: 22
# Local Best Food Source: [-2.50872897 -2.93950132]
# local Best F(x) = -75.95965406339229
# Generation: 23
# Local Best Food Source: [-2.50872897 -2.93950132]
# local Best F(x) = -75.95965406339229
# Generation: 24
# Local Best Food Source: [-3.20965481 -2.46033223]
# local Best F(x) = -73.63068494009676
# Generation: 25
# Local Best Food Source: [-3.20965481 -2.46033223]
# local Best F(x) = -73.63068494009676
# Generation: 26
# Local Best Food Source: [-3.08712698  2.74269722]
# local Best F(x) = -63.57602769178884
# Generation: 27
# Local Best Food Source: [-3.08712698  2.74269722]
# local Best F(x) = -63.57602769178884
# Generation: 28
# Local Best Food Source: [-1.50952971 -2.54660871]
# local Best F(x) = -56.626309138689734
# Generation: 29
# Local Best Food Source: [-1.50952971 -2.54660871]
# local Best F(x) = -56.626309138689734
# Generation: 30
# Local Best Food Source: [2.04705551 2.54796782]
# local Best F(x) = -44.119232938136676
# Generation: 31
# Local Best Food Source: [2.65052404 2.15085479]
# local Best F(x) = -45.83016808112267
# Generation: 32
# Local Best Food Source: [2.65052404 2.15085479]
# local Best F(x) = -45.83016808112267
# Generation: 33
# Local Best Food Source: [-3.29828217 -3.17951577]
# local Best F(x) = -73.82652139429133
# Generation: 34
# Local Best Food Source: [-3.29828217 -3.17951577]
# local Best F(x) = -73.82652139429133
# Generation: 35
# Local Best Food Source: [-3.29828217 -3.17951577]
# local Best F(x) = -73.82652139429133
# Generation: 36
# Local Best Food Source: [-3.8729981   2.63761166]
# local Best F(x) = -42.043736643922045
# Generation: 37
# Local Best Food Source: [-3.8729981   2.63761166]
# local Best F(x) = -42.043736643922045
# Generation: 38
# Local Best Food Source: [-3.32981777 -1.33221908]
# local Best F(x) = -51.51167889386488
# Generation: 39
# Local Best Food Source: [ 2.49039081 -2.80472976]
# local Best F(x) = -63.160618891461965
# Generation: 40
# Local Best Food Source: [ 2.49039081 -2.80472976]
# local Best F(x) = -63.160618891461965
# Generation: 41
# Local Best Food Source: [-2.86508993  2.34813803]
# local Best F(x) = -62.17987942573106
# Generation: 42
# Local Best Food Source: [-2.64276847 -3.25296745]
# local Best F(x) = -74.89060209381284
# Generation: 43
# Local Best Food Source: [-2.64276847 -3.25296745]
# local Best F(x) = -74.89060209381284
# Generation: 44
# Local Best Food Source: [-1.96413009 -2.16278488]
# local Best F(x) = -60.21936280934902
# Generation: 45
# Local Best Food Source: [-3.40241689 -2.16278488]
# local Best F(x) = -65.9984973139902
# Generation: 46
# Local Best Food Source: [-3.40241689 -2.16278488]
# local Best F(x) = -65.9984973139902
# Generation: 47
# Local Best Food Source: [-1.90984421 -1.8507264 ]
# local Best F(x) = -53.46486844078852
# Generation: 48
# Local Best Food Source: [-2.82319179 -1.8507264 ]
# local Best F(x) = -65.21990635408082
# Generation: 49
# Local Best Food Source: [-2.82319179 -1.8507264 ]
# local Best F(x) = -65.21990635408082
# Generation: 50
# Local Best Food Source: [-2.38151286 -1.73005829]
# local Best F(x) = -59.033697403410386
# Generation: 51
# Local Best Food Source: [-2.38151286 -1.73005829]
# local Best F(x) = -59.033697403410386
# Generation: 52
# Local Best Food Source: [-3.09888376  1.87850029]
# local Best F(x) = -55.770046397606436
# Generation: 53
# Local Best Food Source: [-3.09888376  3.31091031]
# local Best F(x) = -57.79790154442683
# Generation: 54
# Local Best Food Source: [-3.04103702  3.31091031]
# local Best F(x) = -58.159583447252196
# Generation: 55
# Local Best Food Source: [-3.23103828 -2.99842849]
# local Best F(x) = -76.10720459262762
# Generation: 56
# Local Best Food Source: [-3.19889447 -2.99842849]
# local Best F(x) = -76.50971068468311
# Generation: 57
# Local Best Food Source: [-3.19889447 -2.99842849]
# local Best F(x) = -76.50971068468311
# Generation: 58
# Local Best Food Source: [ 3.52057192 -2.72035829]
# local Best F(x) = -52.16418272101575
# Generation: 59
# Local Best Food Source: [ 3.52057192 -2.72035829]
# local Best F(x) = -52.16418272101575
# Generation: 60
# Local Best Food Source: [-2.81914499  2.34456585]
# local Best F(x) = -62.05254187748993
# Generation: 61
# Local Best Food Source: [-2.81914499  2.34456585]
# local Best F(x) = -62.05254187748993
# Generation: 62
# Local Best Food Source: [2.18943328 2.74466445]
# local Best F(x) = -46.41535415548395
# Generation: 63
# Local Best Food Source: [2.18943328 2.74466445]
# local Best F(x) = -46.41535415548395
# Generation: 64
# Local Best Food Source: [2.52259097 2.00961221]
# local Best F(x) = -43.483791195064185
# Generation: 65
# Local Best Food Source: [ 3.46565459 -3.00290983]
# local Best F(x) = -54.28241313616934
# Generation: 66
# Local Best Food Source: [ 3.46565459 -3.00290983]
# local Best F(x) = -54.28241313616934
# Generation: 67
# Local Best Food Source: [2.8117395  2.00961221]
# local Best F(x) = -44.095613577659414
# Generation: 68
# Local Best Food Source: [-2.00217386  2.10697456]
# local Best F(x) = -49.433617659242664
# Generation: 69
# Local Best Food Source: [-1.96284877 -3.24049646]
# local Best F(x) = -65.28158313535288
# Generation: 70
# Local Best Food Source: [-1.96284877 -3.24049646]
# local Best F(x) = -65.28158313535288
# Generation: 71
# Local Best Food Source: [-1.35056682 -1.62878393]
# local Best F(x) = -38.08153777120273
# Generation: 72
# Local Best Food Source: [-1.30919343 -2.21485757]
# local Best F(x) = -48.265476477552184
# Generation: 73
# Local Best Food Source: [-3.11673276 -2.28004417]
# local Best F(x) = -72.09908765783996
# Generation: 74
# Local Best Food Source: [-3.11673276 -2.28004417]
# local Best F(x) = -72.09908765783996
# Generation: 75
# Local Best Food Source: [-2.33398307 -2.21485757]
# local Best F(x) = -67.32674065773998
# Generation: 76
# Local Best Food Source: [-2.06727733 -2.21077117]
# local Best F(x) = -62.908425705886614
# Generation: 77
# Local Best Food Source: [-2.06727733 -2.33105005]
# local Best F(x) = -64.76021672559824
# Generation: 78
# Local Best Food Source: [-2.54859225 -2.33105005]
# local Best F(x) = -71.77437276772633
# Generation: 79
# Local Best Food Source: [-2.54859225 -2.33105005]
# local Best F(x) = -71.77437276772633
# Generation: 80
# Local Best Food Source: [-2.66424671 -3.68591155]
# local Best F(x) = -63.86739859146911
# Generation: 81
# Local Best Food Source: [ 2.67661518 -2.97002999]
# local Best F(x) = -64.04722907136367
# Generation: 82
# Local Best Food Source: [ 2.67661518 -2.97002999]
# local Best F(x) = -64.04722907136367
# Generation: 83
# Local Best Food Source: [ 2.67661518 -2.86305365]
# local Best F(x) = -64.09745336646064
# Generation: 84
# Local Best Food Source: [ 2.67661518 -2.86305365]
# local Best F(x) = -64.09745336646064
# Generation: 85
# Local Best Food Source: [ 2.67661518 -2.86305365]
# local Best F(x) = -64.09745336646064
# Generation: 86
# Local Best Food Source: [-1.5344325  -1.59779625]
# local Best F(x) = -41.05947990631125
# Generation: 87
# Local Best Food Source: [-0.99638786 -2.43619079]
# local Best F(x) = -45.898882336424684
# Generation: 88
# Local Best Food Source: [-0.99638786 -2.43619079]
# local Best F(x) = -45.898882336424684
# Generation: 89
# Local Best Food Source: [-4.06018948 -2.74771305]
# local Best F(x) = -44.91968460778952
# Generation: 90
# Local Best Food Source: [-4.06018948 -2.74771305]
# local Best F(x) = -44.91968460778952
# Generation: 91
# Local Best Food Source: [-1.1082815  -2.98653357]
# local Best F(x) = -50.88636289995701
# Generation: 92
# Local Best Food Source: [-1.34665228 -2.43556743]
# local Best F(x) = -52.18065178492412
# Generation: 93
# Local Best Food Source: [-2.41392699 -2.43556743]
# local Best F(x) = -71.6245306678576
# Generation: 94
# Local Best Food Source: [-2.41392699 -2.43556743]
# local Best F(x) = -71.6245306678576
# Generation: 95
# Local Best Food Source: [-1.28741892 -3.2957777 ]
# local Best F(x) = -51.24805227245328
# Generation: 96
# Local Best Food Source: [3.29886433 3.0077523 ]
# local Best F(x) = -43.53137993454828
# Generation: 97
# Local Best Food Source: [-3.31056651  1.22592801]
# local Best F(x) = -43.725080768752804
# Generation: 98
# Local Best Food Source: [ 1.86305254 -3.58003072]
# local Best F(x) = -46.436451392654575
# Generation: 99
# Local Best Food Source: [ 1.86305254 -3.58003072]
# local Best F(x) = -46.436451392654575
# Generation: 100
# Local Best Food Source: [-2.066356   -3.85910011]
# local Best F(x) = -48.102208482976025
# ============================================
# Time Consume：0.066705
# Best Food Source: [-3.19889447 -2.99842849]
# Best F(x) = -76.50971068468311
